# %%
url = "https://www.joshstrupp.com/"
print (soup.get_text(url))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b4391ee0cce5> in <module>
#       1 url = "https://www.joshstrupp.com/"
# ----> 2 print (soup.get_text(url))
#
# NameError: name 'soup' is not defined

# %%
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, "lxml")

url = "https://www.joshstrupp.com/"
print (soup.get_text(url))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d71ee63493df> in <module>
#       7 from bs4 import BeautifulSoup
#       8
# ----> 9 soup = BeautifulSoup(r, "lxml")
#      10
#      11 url = "https://www.joshstrupp.com/"
#
# NameError: name 'r' is not defined

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen

url = "https://www.joshstrupp.com/"
html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')

text = soup.get_text()
print (text.count('Product' or 'Fake' or 'Josh'))
# Out:
# 8

# %%
import bs4
import re

data = 'https://www.amerisourcebergen.com/about-who-we-are'

# ''''
# <html>
# <body>
# <div>today is a sunny day</div>
# <div>I love when it's sunny outside</div>
# Call me sunny
# <div>sunny is a cool word sunny</div>
# </body>
# </html>
# ''''

searched_word = 'innovate'

soup = bs4.BeautifulSoup(data, 'html.parser')
results = soup.body.find_all(string=re.compile('.*{0}.*'.format(searched_word)), recursive=True)

print 'Found the word "{0}" {1} times\n'.format(searched_word, len(results))

for content in results:
    words = content.split()
    for index, word in enumerate(words):
        # If the content contains the search word twice or more this will fire for each occurence
        if word == searched_word:
            print 'Whole content: "{0}"'.format(content)
            before = None
            after = None
            # Check if it's a first word
            if index != 0:
                before = words[index-1]
            # Check if it's a last word
            if index != len(words)-1:
                after = words[index+1]
            print '\tWord before: "{0}", word after: "{1}"'.format(before, after)
# Out:
#   File "<ipython-input-65-08c761accdb9>", line 22
#     print 'Found the word "{0}" {1} times'\n.format(searched_word, len(results))
#                                          ^
# SyntaxError: invalid syntax

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen

url = "https://www.amerisourcebergen.com/about-who-we-are"
html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')


innovation_instances = soup.find_all(string=re.compile("inno*"))
print(innovation_instances)

# text = soup.get_text()
# print (text.count('Product' or 'Fake' or 'Josh'))
# Out:
# ['Powered by our associates around the world, we provide the pharmaceutical products and business solutions that improve access to care. We operate the backbone of the healthcare supply chain. We drive the future of local care delivery. We guide medical innovations to market. This is what it means to create healthier futures.', "Helping people access the healthcare products they need is in our DNA. Whether through product sourcing and distribution, supporting community-based care or partnering with manufacturers to bring an innovative product to market, our commitment to improving patients' lives makes all the difference."]

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import csv

url = "https://www.amerisourcebergen.com/about-who-we-are"
html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')


innovation_instances = soup.find_all(string=re.compile("inno*"))
# print(innovation_instances)

def createCSV():
    with open("innovation_sentences.csv", mode="w") as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(["Amerisourcebergen"])
        csvwriter.writerow([innovation_instances])
        
createCSV()

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import json

url = "https://www.amerisourcebergen.com/about-who-we-are"
html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')


innovation_instances = soup.find_all(string=re.compile("inno*"))
# print(innovation_instances)

data = {'AmeriSource':[{'all_instances': innovation_instances}]}

with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import json

# define two URLs for two different companies
url = "https://www.amerisourcebergen.com/about-who-we-are"
url2 = "https://www.aboutamazon.com/our-company"

html = urlopen(url)
html2 = urlopen(url2)

soup = BeautifulSoup(html, 'html.parser')
soup2 = BeautifulSoup(html2, 'html.parser')

innovation_instances_AmeriSource = soup.find_all(string=re.compile("inno*"))
innovation_instances_Amazon = soup2.find_all(string=re.compile("inno*"))

data = {'AmeriSource':[{'all_instances': innovation_instances_AmeriSource}]},{'Amazon':[{'all_instances': innovation_instances_Amazon}]}

with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import json

# define two URLs for two different companies
url = "https://www.amerisourcebergen.com/about-who-we-are"
url2 = "https://www.aboutamazon.com/our-company"

html = urlopen(url)
html2 = urlopen(url2)

soup = BeautifulSoup(html, 'html.parser')
soup2 = BeautifulSoup(html2, 'html.parser')

innovation_instances_AmeriSource = soup.find_all(string=re.compile("inno*"))
innovation_instances_Amazon = soup2.find_all(string=re.compile("inno*"))

data = {'AmeriSource':[{'all_instances': innovation_instances_AmeriSource}]},{'Amazon':[{'all_instances': innovation_instances_Amazon}]}

with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import json

urls = ['https://www.aboutamazon.com/our-company', 'https://www.amerisourcebergen.com/about-who-we-are']
data = {}

for url in urls:
    
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    innovation_instances = soup.find_all(string=re.compile("inno*"))
    
    data[url] = innovation_instances

with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)
    
    
print(data)
# Out:
# {'https://www.aboutamazon.com/our-company': ['From the lab to the fulfillment center, employees contributed to the innovations behind a mailer that can be recycled in the same bin as Amazon’s iconic box.', 'Our innovations'], 'https://www.amerisourcebergen.com/about-who-we-are': ['Powered by our associates around the world, we provide the pharmaceutical products and business solutions that improve access to care. We operate the backbone of the healthcare supply chain. We drive the future of local care delivery. We guide medical innovations to market. This is what it means to create healthier futures.', "Helping people access the healthcare products they need is in our DNA. Whether through product sourcing and distribution, supporting community-based care or partnering with manufacturers to bring an innovative product to market, our commitment to improving patients' lives makes all the difference."]}

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import csv

urls = ['https://www.aboutamazon.com/our-company', 'https://www.amerisourcebergen.com/about-who-we-are']
data = {}

for url in urls:
    
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    innovation_instances = soup.find_all(string=re.compile("inno*"))
    
    data[url] = innovation_instances

def createCSV():
    with open("data.csv", mode="w") as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow([data])
        
createCSV()

# %%
#GOAL: Clean up JSON output – add count of "innovation" words for each website, create cleaner, structured data

#NOTE: there are simple JSON to CSV converters: https://json-csv.com

# ------------------------------------------

from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import json

#Use "String slices" and .title() method to entract name of company after 'http://www.'

urls = ['https://www.aboutamazon.com/our-company', 'https://www.volkswagenag.com/en/group.html', 'https://www.samsung.com/us/aboutsamsung/home/', 'https://www.intel.com/content/www/us/en/company-overview/company-overview.html','https://www.microsoft.com/en-us/about', 'https://www.roche.com/about.htm','https://www.merck.com/about/home.html','https://www.boeing.com/company/general-info/', 'https://www.fico.com/en/about-us','https://www.arconic.com/what-we-do/','https://insmed.com/about/','http://www.epizyme.com/about-us/overview-history/','https://www.csgi.com/company/','https://www.overstock.com/about']
data = {}

for url in urls:
    
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    innovation_instances = soup.find_all(string=re.compile("inno*"))
    
    # add count of innovation words to dictionary and print as JSON/CSV element under 
    
    data[url] = innovation_instances
    
    #Convert innovation_instances to string and count instances
    
    def listToString():  
        ii_string = " " 

        # return string   
        return (ii_string.join(innovation_instances)) 

    string = listToString()
    sub = 'inno'
    
    inno_string = (string.count(sub))
    
    print (inno_string)
    
    innovation_instances.append(inno_string)
    
    
with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)
    
print(data)
# Out:
# 2
# 2
# 3
# {'https://www.aboutamazon.com/our-company': ['From the lab to the fulfillment center, employees contributed to the innovations behind a mailer that can be recycled in the same bin as Amazon’s iconic box.', 'Our innovations', 2], 'https://www.amerisourcebergen.com/about-who-we-are': ['Powered by our associates around the world, we provide the pharmaceutical products and business solutions that improve access to care. We operate the backbone of the healthcare supply chain. We drive the future of local care delivery. We guide medical innovations to market. This is what it means to create healthier futures.', "Helping people access the healthcare products they need is in our DNA. Whether through product sourcing and distribution, supporting community-based care or partnering with manufacturers to bring an innovative product to market, our commitment to improving patients' lives makes all the difference.", 2], 'https://www.unitedhealthgroup.com/about': ['\r\n        {"navItems":[{"active":true,"navTitle":"About Us","confTitle":"About","href":"/content/uhg/en/about.html","title":"About","children":[{"active":false,"navTitle":"Our History","confTitle":"Our History","href":"/content/uhg/en/about/history.html","title":"Our History","children":[]},{"active":false,"navTitle":"Mission & Values","confTitle":"Mission & Values","href":"/content/uhg/en/about/mission-values.html","title":"Mission & Values","children":[]},{"active":false,"navTitle":"Executives","confTitle":"Executives","href":"/content/uhg/en/about/executives.html","title":"Executives","children":[]},{"active":false,"navTitle":"Corporate Governance","confTitle":"Corporate Governance","href":"/content/uhg/en/about/corporate-governance.html","title":"Corporate Governance ","children":[]},{"active":false,"navTitle":"Ethics & Integrity","confTitle":"Ethics & Integrity","href":"/content/uhg/en/about/ethics-integrity.html","title":"Ethics & Integrity","children":[]},{"active":false,"navTitle":"Research & Development","confTitle":"Research & Development","href":"/content/uhg/en/about/innovation.html","title":"Research & Development","children":[]},{"active":false,"navTitle":"Health Care Modernization","confTitle":"Health Care Modernization","href":"/content/uhg/en/about/modernization.html","title":"Health Care Modernization","children":[{"active":false,"navTitle":"Modernization Strategies","confTitle":"Modernization Strategies","href":"/content/uhg/en/about/modernization/ideas.html","title":"Strategies ","children":[]},{"active":false,"navTitle":"Key Issues","confTitle":"Key Issues","href":"/content/uhg/en/about/modernization/key-issues.html","title":"Key Issues","children":[{"active":false,"navTitle":"Affordability","confTitle":"Affordability","href":"/content/uhg/en/about/modernization/key-issues/affordability.html","title":"Affordability","children":[]},{"active":false,"navTitle":"Increasing Coverage","confTitle":"Increasing Coverage","href":"/content/uhg/en/about/modernization/key-issues/increasing-coverage.html","title":"Increasing Coverage","children":[]},{"active":false,"navTitle":"Children\'s Health","confTitle":"Children\'s Health","href":"/content/uhg/en/about/modernization/key-issues/childrens-health.html","title":"Children\'s Health","children":[]},{"active":false,"navTitle":"Chronic Conditions","confTitle":"Chronic Conditions","href":"/content/uhg/en/about/modernization/key-issues/chronic-conditions.html","title":"Chronic Conditions","children":[]},{"active":false,"navTitle":"Health IT & Innovation","confTitle":"Health IT & Innovation","href":"/content/uhg/en/about/modernization/key-issues/health-it.html","title":"Health IT & Innovation","children":[]},{"active":false,"navTitle":"Medicare & Medicaid Modernization","confTitle":"Medicare & Medicaid Modernization","href":"/content/uhg/en/about/modernization/key-issues/medicare-medicaid.html","title":"Medicare Medicaid","children":[]},{"active":false,"navTitle":"Pharmacy Care Services","confTitle":"Pharmacy Care Services","hr ...

# %%
#GOAL: Clean up JSON output – add count of "innovation" words for each website, create cleaner, structured data

#NOTE: there are simple JSON to CSV converters: https://json-csv.com

# ------------------------------------------

from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import json

#Use "String slices" and .title() method to entract name of company after 'http://www.'
# remove s from https
# add logic that skips URLs that give `HTTPError` OR add logic to bypass HTTP Error 403 - https://stackoverflow.com/questions/13055208/httperror-http-error-403-forbidden
# used US companies only



urls = ['http://www.aboutamazon.com/our-company/', 
#         'http://www.volkswagenag.com/en/group.html', 
        'http://www.intel.com/content/www/us/en/company-overview/company-overview.html',
        'http://www.microsoft.com/en-us/about/',
#         'http://www.jnj.com/about-jnj/',
        'http://corporate.ford.com/company.html',
        'http://www.boeing.com/company/general-info/',
        'http://www.alliancedata.com/about-us/default.aspx',
#         'http://www.irobot.com/about-irobot/company-information/',
        'https://www.polarityte.com/about/overview/',
        'http://www.arconic.com/what-we-do/',
        'http://www.fico.com/en/about-us/',
        'http://www.epizyme.com/about-us/overview-history/']
data = {}

for url in urls:
    
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    innovation_instances = soup.find_all(string=re.compile("inno*"))
    
    # add count of innovation words to dictionary and print as JSON/CSV element under 
    
    data[url] = innovation_instances
    
    #Convert innovation_instances to string and count instances
    
    def listToString():  
        ii_string = " " 

        # return string   
        return (ii_string.join(innovation_instances)) 

    string = listToString()
    sub = 'inno'
    
    inno_string = (string.count(sub))
    
    print (inno_string)
    
#     innovation_instances.append(inno_string)
    
    
# with open('data.txt', 'w') as outfile:
#     json.dump(data, outfile)
# Out:
# 2
# 0
# 1
# 1
# 5
# 0
# 1
# 1
# 2
# 0

# %%
soup.title
# Out:
# <title>About Amazon</title>

# %%
import sys
print(sys.version)
# Out:
# 3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
soup_object = soup('<title>', 'lxml')
tag = soup_object.title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-65904b72a5b8> in <module>
#       1 soup_object = soup('<title>', 'lxml')
# ----> 2 tag = soup_object.title
#
# ~/opt/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    1576     def __getattr__(self, key):
#    1577         raise AttributeError(
# -> 1578             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1579         )
#
# AttributeError: ResultSet object has no attribute 'title'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
type(site_title)
# Out:
# bs4.element.ResultSet

# %%
for string in soup.stripped_strings:
    print(repr(string))
# Out:
# "body[data-dayofweek='0'] .mood-color,\n        body[data-dayofweek='0'] .mood-color *:link,\n        body[data-dayofweek='0'] .mood-color *:visited,\n        body[data-dayofweek='0'] .mood-color:before {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='0'] .mood-bgcolor {\n        background-color: #007cb6\n;\n        }\n        body[data-dayofweek='0'] .mood-fill {\n        fill: #007cb6\n;\n        }\n        body[data-dayofweek='0'] .mood-hover:hover {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='0'] .mood-list li:before {\n        color: #007cb6\n;\n        }\n    \n    \n        body[data-dayofweek='1'] .mood-color,\n        body[data-dayofweek='1'] .mood-color *:link,\n        body[data-dayofweek='1'] .mood-color *:visited,\n        body[data-dayofweek='1'] .mood-color:before {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='1'] .mood-bgcolor {\n        background-color: #007cb6\n;\n        }\n        body[data-dayofweek='1'] .mood-fill {\n        fill: #007cb6\n;\n        }\n        body[data-dayofweek='1'] .mood-hover:hover {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='1'] .mood-list li:before {\n        color: #007cb6\n;\n        }\n    \n    \n        body[data-dayofweek='2'] .mood-color,\n        body[data-dayofweek='2'] .mood-color *:link,\n        body[data-dayofweek='2'] .mood-color *:visited,\n        body[data-dayofweek='2'] .mood-color:before {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='2'] .mood-bgcolor {\n        background-color: #007cb6\n;\n        }\n        body[data-dayofweek='2'] .mood-fill {\n        fill: #007cb6\n;\n        }\n        body[data-dayofweek='2'] .mood-hover:hover {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='2'] .mood-list li:before {\n        color: #007cb6\n;\n        }\n    \n    \n        body[data-dayofweek='3'] .mood-color,\n        body[data-dayofweek='3'] .mood-color *:link,\n        body[data-dayofweek='3'] .mood-color *:visited,\n        body[data-dayofweek='3'] .mood-color:before {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='3'] .mood-bgcolor {\n        background-color: #007cb6\n;\n        }\n        body[data-dayofweek='3'] .mood-fill {\n        fill: #007cb6\n;\n        }\n        body[data-dayofweek='3'] .mood-hover:hover {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='3'] .mood-list li:before {\n        color: #007cb6\n;\n        }\n    \n    \n        body[data-dayofweek='4'] .mood-color,\n        body[data-dayofweek='4'] .mood-color *:link,\n        body[data-dayofweek='4'] .mood-color *:visited,\n        body[data-dayofweek='4'] .mood-color:before {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='4'] .mood-bgcolor {\n        background-color: #007cb6\n;\n        }\n        body[data-dayofweek='4'] .mood-fill {\n        fill: #007cb6\n;\n        }\n        body[data-dayofweek='4'] .mood-hover:hover {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='4'] .mood-list li:before {\n        color: #007cb6\n;\n        }\n    \n    \n        body[data-dayofweek='5'] .mood-color,\n        body[data-dayofweek='5'] .mood-color *:link,\n        body[data-dayofweek='5'] .mood-color *:visited,\n        body[data-dayofweek='5'] .mood-color:before {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='5'] .mood-bgcolor {\n        background-color: #007cb6\n;\n        }\n        body[data-dayofweek='5'] .mood-fill {\n        fill: #007cb6\n;\n        }\n        body[data-dayofweek='5'] .mood-hover:hover {\n        color: #007cb6\n;\n        }\n        body[data-dayofweek='5'] .mood-list li:before {\n        color: #007cb6\n;\n        }\n    \n    \n        body[data-dayofweek='6'] .mood-color,\n        body[data-dayofweek='6'] .mood-color *:link,\n        body[data-dayofweek='6'] .mood-color *:visited,\n        body[data-dayofweek='6'] .mood-color:before ...
# '@media only screen and (min-width: 768px) {\r\n    .TourRegistrationForm[data-step="1"] .TourRegistrationFieldsetOne {\r\n        min-height: 480px !important;  \r\n    }\r\n}'
# '@media only screen and (max-width: 568px) {\r\n    .TourRegistrationForm-promos-promo {\r\n        margin-top: 10px;\r\n    }\r\n}\r\n@media only screen and (min-width: 568px) {\r\n    .TourRegistrationForm-promos-promo {\r\n        margin-top: 30px;\r\n    }\r\n}'
# '@media only screen and (min-width: 1051px) {\r\n    .TourRegistrationFieldsetThree-items-item-row .CheckboxInput-label {\r\n        width: calc(100% + 30px);\r\n    }\r\n}'
# '@media only screen and (min-width: 768px) {\r\n    .TourRegistrationFieldsetThree-items {\r\n        width: 672px;\r\n        max-width: 672px;\r\n    }\r\n}'
# '@media only screen and (max-width: 568px) {\r\n    .TourRegistrationCalendarComingSoon.left {\r\n         left: 25%;\r\n         width: 100%;\r\n         margin-left: -25%;\r\n    }\r\n}\r\n\r\n@media only screen and (min-width: 568px) {\r\n    .TourRegistrationCalendarComingSoon.left {\r\n         left: 0;\r\n         width: auto;\r\n         margin-left: 0;\r\n    }\r\n}'
# '.SearchResultsPage-formInput {\r\n    padding: 0 0 0 18px;\r\n}\r\n\r\n@media only screen and (min-width: 768px) {\r\n    .SearchResultsPage-form-wrapper {\r\n        display: block;\r\n        max-width: none;\r\n    }\r\n    \r\n    .SearchResultsPage-form-form {\r\n        left: 5%;\r\n    }\r\n    \r\n    .SearchResultsPage-formInput {\r\n        padding: 0 0 0 24px;\r\n    }\r\n}\r\n\r\n@media only screen and (min-width: 790px) {\r\n    .SearchResultsPage-form-form {\r\n        left: calc(50% - 350px);\r\n    }\r\n}\r\n\r\n@media only screen and (min-width: 1440px) {\r\n    .SearchResultsPage-form-form {\r\n        left: calc(50% - 430px);\r\n    }\r\n}'
# '.RoundupPage-contentWrapper {\r\n    padding-top: 0;\r\n}\r\n\r\n.RoundupPage-lead {\r\n    padding-top: 100px;\r\n}\r\n\r\n@media only screen and (min-width: 768px) {\r\n    .RoundupPage-lead {\r\n        padding-top: 0;\r\n    }\r\n}\r\n\r\n.RichTextArticleBody .cms-textAlign-center {\r\n    text-align: center;\r\n}'
# '.MapPage-mainContent[data-map-hide-legend="true"] .MapPage-map-legend-wrapper {\r\n    display: none;\r\n}'
# '@media only screen and (min-width: 1024px) {\r\n\t.CategoryPage-breadcrumbs-item:last-of-type {\r\n\t\tfont-size: 39px;\r\n\t}\r\n}\r\n\r\n@media only screen and (min-width: 1200px) {\r\n\t.CategoryPage-breadcrumbs-item:last-of-type {\r\n\t\tfont-size: 46px;\r\n\t}\r\n}\r\n\r\n@media only screen and (min-width: 1440px) {\r\n\t.CategoryPage-breadcrumbs-item:last-of-type {\r\n\t\tfont-size: 50px;\r\n\t}\r\n}'
# '@media only screen and (min-width:768px) {\r\n    .FaqItem-question { \r\n        margin-top: 35px; \r\n    }\r\n  .ListFaq [data-list-faq-anchor] {\r\n    height: 1px;\r\n    width: 1px;\r\n    position: absolute;\r\n    left: 0;\r\n    top: -100px;\r\n  }\r\n  .ListFaq [data-list-faq-anchor]:before {\r\n    height: 1px !important;\r\n    margin: 0 !important;\r\n    width: 1px;\r\n  }\r\n}'
# 'About Amazon'
# '{"image":"https://d39w7f4ix9f5s9.cloudfront.net/89/10/1ce6dd514a598270e60ac626fef6/hero.JPG","@type":"WebPage","description":"Learn more about Amazon.","@context":"http://schema.org","headline":"About Amazon","url":"https://www.aboutamazon.com/our-company"}'
# '/**\n         This allows us to load the IE polyfills via feature detection so that they do not load\n         needlessly in the browsers that do not need them. It also ensures they are loaded\n         non async so that they load before the rest of our JS.\n         */\n        var head = document.getElementsByTagName(\'head\')[0];\n        if (!window.CSS || !window.CSS.supports || !window.CSS.supports("(--fakeColor: red)")) {\n            var script = document.createElement(\'script\');\n            script.setAttribute(\'src\', "https://d39w7f4ix9f5s9.cloudfront.net/resource/00000162-022f-d25e-a5ee-b6ff57130000/styleguide/utils/IE11Polyfills.min.afc742c9bcc06b151ff709c4dd900791.js");\n            script.setAttribute(\'type\', \'text/javascript\');\n            script.async = false;\n            head.appendChild(script);\n        }'
# 'window.fbAsyncInit = function() {\n    FB.init({\n    \n        appId : \'2194788737494754\',\n    \n    xfbml : true,\n    version : \'v2.9\'\n    });\n    };\n    (function(d, s, id){\n    var js, fjs = d.getElementsByTagName(s)[0];\n    if (d.getElementById(id)) {return;}\n    js = d.createElement(s); js.id = id;\n    js.src = "//connect.facebook.net/en_US/sdk.js";\n    fjs.parentNode.insertBefore(js, fjs);\n    }(document, \'script\', \'facebook-jssdk\'));'
# "document.addEventListener('DOMContentLoaded', function (event) {\r\n  const externalLinkQualifiers = document.querySelectorAll('[class$=-main] .PromoTextItem, [data-main-navigation] .NavigationLink, .ListOrdered-items-item a')\r\n\r\n  if (externalLinkQualifiers) {\r\n    externalLinkQualifiers.forEach(function(item) {\r\n      if (item.href) {\r\n        if ((item.href.indexOf(window.location.origin) === -1) && (item.href.indexOf('blog.aboutamazon.com') === -1)) {\r\n          item.setAttribute('data-external-link', true)\r\n        }\r\n      }\r\n    })\r\n  }\r\n\r\n  const dayoneLinkQualifiers = document.querySelectorAll('.PromoImageOnTop-small h3 .Link')\r\n\r\n  if (dayoneLinkQualifiers) {\r\n    dayoneLinkQualifiers.forEach(function(item) {\r\n      if (item.href) {\r\n        if (item.href.indexOf('blog.aboutamazon.com') > -1) {\r\n          item.parentNode.parentNode.setAttribute('data-dayone-link', true)\r\n        }\r\n      }\r\n    })\r\n  }\r\n})"
# "document.addEventListener('DOMContentLoaded', function() {\n    var body = document.getElementsByTagName('body')[0]\n    if (body) {\n    body.setAttribute('data-dayofweek', new Date().getDay())\n    }\n    })"
# 'Facebook'
# 'Google Plus'
# 'Instagram'
# 'Mail To'
# 'LinkedIn'
# 'Pinterest'
# 'Quotation Mark'
# 'Tumblr'
# 'Twitter'
# 'Youtube'
# 'RSS'
# 'magnify'
# 'greater than'
# 'Quote'
# 'Close'
# 'Search'
# 'Right arrow'
# 'Icon for read more (cta)'
# 'Download Icon'
# 'Whatsapp Icon'
# 'Back to Amazon'
# 'us'
# 'au'
# 'br'
# 'ca'
# 'cn'
# 'de'
# 'fr'
# 'in'
# 'it'
# 'jp'
# 'mx'
# 'nl'
# 'es'
# 'uk'
# 'us'
# 'Site Navigation'
# 'Investors'
# 'Press center'
# 'The Spheres'
# 'Get the latest news in your inbox'
# 'en'
# 'en'
# 'Visit a different Amazon site'
# 'European Union'
# 'English'
# 'France'
# 'Français'
# 'Germany  (Deutschland)'
# 'Deutsch'
# 'India'
# 'English'
# 'Italy (Italia)'
# 'Italiano'
# 'Spain (España)'
# 'Español'
# 'United Kingdom'
# 'English'
# 'United States'
# 'English'
# 'Menu'
# 'Close'
# 'Who we are'
# 'Leadership Principles'
# 'Working at Amazon'
# 'Diversity and inclusion'
# 'Awards and recognition'
# 'Amazon fulfillment centers'
# 'Take a tour of Amazon'
# 'Small business'
# 'Authors'
# 'Job creation and investment'
# 'Investing in the U.S.'
# 'Sustainability'
# 'Community'
# 'Our Positions'
# 'Press resources'
# 'Investor resources'
# 'Day One: The Amazon Blog'
# 'Our Business'
# 'Amazon Prime'
# 'Company news'
# 'Devices'
# 'Entertainment'
# 'Innovation'
# 'Job creation & investment'
# 'Operations'
# 'Small business'
# 'Transportation'
# 'Amazon Blogs'
# 'Alexa Developer Blog'
# 'Amazon Developer Blog'
# 'Amazon Business Blog'
# 'AWS News Blog'
# 'Prime Insider'
# 'Amazon Design'
# 'Our Communities'
# 'Community'
# 'Policy'
# 'Sustainability'
# 'Work Here'
# 'Amazon offices'
# 'Working at Amazon'
# 'Amazon.jobs'
# 'Search'
# 'Search'
# 'Close'
# 'Back To Top'
# 'en'
# 'en'
# 'Visit a different Amazon site'
# 'European Union'
# 'English'
# 'France'
# 'Français'
# 'Germany  (Deutschland)'
# 'Deutsch'
# 'India'
# 'English'
# 'Italy (Italia)'
# 'Italiano'
# 'Spain (España)'
# 'Español'
# 'United Kingdom'
# 'English'
# 'United States'
# 'English'
# 'Investing in the U.S.'
# 'Since 2011, Amazon has invested over $160 billion in the US, including infrastructure and compensation to our employees – $53 billion in 2017 alone.'
# 'Continue Reading'
# 'About Amazon'
# 'Learn more about Amazon.'
# 'Learn more about Amazon'
# 'Investing in the U.S.'
# 'Investors'
# 'Press room'
# 'Select awards & recognition'
# "Tour Amazon's headquarters"
# 'Amazon Fulfillment Center Tours'
# 'Our Company'
# 'About Amazon'
# 'Amazon is guided by four principles: customer obsession rather than competitor focus, passion for invention, commitment to operational excellence, and long-term thinking.'
# 'Continue Reading'
# 'Company news'
# '2018 Letter to Shareholders'
# 'To our shareowners: Something strange and remarkable has happened over the last 20 years.'
# 'Continue Reading'
# 'Company news'
# 'Amazon’s actions to help customers, communities, and employees affected by COVID-19'
# 'A roundup of actions Amazon has taken to reduce the spread of the coronavirus while supporting those directly and indirectly impacted by COVID-19.'
# 'Continue Reading'
# 'Operations'
# 'Amazon ramps hiring, opening 100,000 new roles to support people relying on Amazon’s service in this stressful time'
# 'Company will invest over $350 million globally to increase pay by $2/hour in the U.S., £2/hr in the UK, and approximately €2/hr in many EU countries for employees and partners who are in fulfillment centers, transportation operations, stores or those making deliveries so that others can remain at home.'
# 'Continue Reading'
# 'Operations'
# 'Same-Day Delivery just got faster'
# 'Prime members in eligible cities can enjoy free delivery throughout the day on up to 3 million items.'
# 'Continue Reading'
# 'Working at Amazon'
# 'COVID-19 update: More ways Amazon is supporting employees and contractors'
# 'The health and safety of our employees and contractors around the world continues to be our top priority as we face the challenges and questions associated with COVID-19.'
# 'Continue Reading'
# 'Innovation'
# 'Amazon re:MARS 2020 registration now open'
# 'Join Jeff Bezos, Jon Favreau, and others at Amazon’s event dedicated to Machine learning, Automation, Robotics, and Space in Las Vegas, on June 16-19, 2020.'
# 'Continue Reading'
# 'Sustainability'
# 'Go behind the scenes as Amazon develops a new electric vehicle'
# '100,000 electric delivery vans will save millions of metric tons of carbon per year.'
# 'Continue Reading'
# 'Sustainability'
# 'Driving design to combat climate change'
# 'Delivery associates helped design Amazon’s new fleet of electric delivery vehicles with safety and sustainability in mind.'
# 'Continue Reading'
# 'Community'
# 'Amazon stands with our Nashville neighbors'
# 'Delivering relief to people affected by the Tennessee tornadoes.'
# 'Continue Reading'
# 'Job creation and investment'
# 'Helping local small businesses through the impacts of COVID-19'
# 'Amazon is creating a $5 million Neighborhood Small Business Relief Fund to provide cash grants to Seattle small businesses that need assistance.'
# 'Continue Reading'
# 'Sustainability'
# "What went into Amazon's new recyclable mailer"
# 'From the lab to the fulfillment center, employees contributed to the innovations behind a mailer that can be recycled in the same bin as Amazon’s iconic box.'
# 'Continue Reading'
# 'Working at Amazon'
# 'Women powering Amazon'
# 'Building the future on behalf of Amazon customers.'
# 'Continue Reading'
# 'Community'
# 'Amazon contributes $1 million to a new Seattle Foundation fund for community members affected by COVID-19'
# 'Learn about the newly formed COVID-19 Response Fund made up of philanthropy, government, and business partners in the Puget Sound-area, and how you can contribute to help.'
# 'Continue Reading'
# 'More stories'
# 'Small business'
# 'Amazon champions women-owned businesses'
# 'The company announces a year-long partnership with International Women’s Day and launches first-of-its-kind collaboration with fashion icon Diane von Furstenberg supporting sellers, Amazonians, and artists.'
# 'Continue Reading'
# 'Community'
# 'How Amazon is supporting victims of the Australia bushfire crisis'
# 'What the company is doing for support organizations on the frontline of the Australian bushfire crisis, and how you can help.'
# 'Continue Reading'
# 'Books and authors'
# 'The Year in Books 2019'
# 'A look at the most sold, most read, and most loved books of the year.'
# 'Continue Reading'
# 'Read More'
# 'Committed to a sustainable future'
# 'Amazon is making big changes to protect the planet.'
# 'see our goals'
# 'Shop Amazon.com'
# 'Back to Amazon'
# 'us'
# 'au'
# 'br'
# 'ca'
# 'cn'
# 'de'
# 'fr'
# 'in'
# 'it'
# 'jp'
# 'mx'
# 'nl'
# 'es'
# 'uk'
# 'us'
# 'Who we are'
# 'Our Positions'
# 'Leadership Principles'
# 'Take a tour of Amazon'
# 'Working at Amazon'
# 'Amazon fulfillment centers'
# 'Diversity and inclusion'
# 'Awards and recognition'
# 'Building the future'
# 'Our innovations'
# 'Small business'
# 'Authors'
# 'Job creation and investment'
# 'Sustainability'
# 'Community'
# 'What we do'
# 'Shop amazon.com'
# 'Amazon Web Services'
# 'Prime Video'
# 'Amazon Music'
# 'Fire Tablets'
# 'Fire TV'
# 'Echo and Alexa'
# 'Kindle E-readers and Books'
# 'Learn more'
# 'The Day One blog'
# 'Letters to Shareholders'
# 'Press resources'
# 'Investor resources'
# 'Careers at Amazon'
# 'Tour an Amazon Fulfillment Center'
# 'Sign up for our newsletter'
# 'Privacy'
# 'Amazon.com'
# '|'
# 'Conditions of Use'
# '| © 1996-2020 Amazon.com, Inc. or its affiliates'
# "let parentClass = '.vex'\n        let grecaptchaWidgetId = ''\n        let grecaptchaSitekey = ''\n\n        function interstitialOnloadCallback () {\n            grecaptchaSitekey = document.querySelector('.ofd-button').dataset.sitekey\n            if (grecaptchaSitekey) {\n                // Here we need to specifically use the .vex copy of the .ofd-button in order to listen on the click\n                let grecaptchaElement = document.querySelector(parentClass + ' .ofd-button')\n                if (grecaptchaElement) {\n                    grecaptchaWidgetId = grecaptcha.render(grecaptchaElement, {\n                        'sitekey': grecaptchaSitekey,\n                        'callback' : interstitialRecaptchaCallback,\n                        'expiredCallback': interstitialExpiredCallback,\n                        'size' : 'invisible'\n                    })\n                }\n            }\n        }\n\n        function interstitialRecaptchaCallback (token) {\n            let ofdUtils = new window.ofdUtils(grecaptcha, grecaptchaWidgetId, token, parentClass)\n            if (ofdUtils) {\n                ofdUtils.recaptchaCallback()\n            }\n        }\n\n        // Automatically resets recaptcha after expiration, set as callback function for data-expired-callback attribute\n        function interstitialExpiredCallback () {\n            if (grecaptcha) {\n                grecaptcha.reset()\n            }\n        }"
# 'X'
# 'Out for Delivery'
# 'Thank you!'
# 'Please try again'
# 'Quick news and rich insights from inside Amazon, delivered directly to your inbox every few weeks.'
# 'Check your inbox shortly for your very first Out for Delivery email. We’ll reach out every few weeks with more.'
# 'If you’re not redirected back to the blog in a few seconds,'
# 'click here.'
# 'Looks like we had some trouble authenticating your entry. Let’s try again...'
# 'Protected by reCAPTCHA. The Google'
# 'Privacy Policy'
# 'and'
# 'Terms of Service'
# 'apply.'
# 'Sign up'
# 'Not Today'
# 'Amazon Privacy Policy'
# '| Opt-out Anytime'
# '(function(s, p, d) {\r\nvar h=d.location.protocol, i=p+"-"+s,\r\ne=d.getElementById(i), r=d.getElementById(p+"-root"),\r\nu=h==="https:"?"d1z2jf7jlzjs58.cloudfront.net"\r\n:"static."+p+".com";\r\nif (e) return;\r\ne = d.createElement(s); e.id = i; e.async = true;\r\ne.src = h+"//"+u+"/p.js"; r.appendChild(e);\r\n})("script", "parsely", document);'
# '_linkedin_partner_id = "582956";\r\nwindow._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];\r\nwindow._linkedin_data_partner_ids.push(_linkedin_partner_id);'
# '(function(){var s = document.getElementsByTagName("script")[0];\r\nvar b = document.createElement("script");\r\nb.type = "text/javascript";b.async = true;\r\nb.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";\r\ns.parentNode.insertBefore(b, s);})();'
# '// Alexa Certification\r\n_atrk_opts = { atrk_acct:"bSTXp1d0RC20XR", domain:"aboutamazon.com",dynamic: true};\r\n(function() { var as = document.createElement(\'script\'); as.type = \'text/javascript\'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName(\'script\')[0];s.parentNode.insertBefore(as, s); })();'

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import json

#Use "String slices" and .title() method to entract name of company after 'http://www.'
# remove s from https
# add logic that skips URLs that give `HTTPError` OR add logic to bypass HTTP Error 403 - https://stackoverflow.com/questions/13055208/httperror-http-error-403-forbidden
# used US companies only

urls = ['http://www.aboutamazon.com/our-company/', 
#         'http://www.volkswagenag.com/en/group.html', 
        'http://www.intel.com/content/www/us/en/company-overview/company-overview.html',
        'http://www.microsoft.com/en-us/about/',
#         'http://www.jnj.com/about-jnj/',
        'http://corporate.ford.com/company.html',
        'http://www.boeing.com/company/general-info/',
        'http://www.alliancedata.com/about-us/default.aspx',
#         'http://www.irobot.com/about-irobot/company-information/',
        'https://www.polarityte.com/about/overview/',
        'http://www.arconic.com/what-we-do/',
        'http://www.fico.com/en/about-us/',
        'http://www.epizyme.com/about-us/overview-history/']

data = {}

for url in urls:
    
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    
    first_title = soup.title
    
    title = first_title.string
    innovation_instances = soup.find_all(string=re.compile("inno*"))
    
    
    # add count of innovation words to dictionary and print as JSON/CSV element under 
    
    data[url] = innovation_instances, title
    
    def listToString():  
        ii_string = " " 

        # return string   
        return (ii_string.join(innovation_instances)) 

    string = listToString()
    sub = 'inno'
    
    inno_string = (string.count(sub))
    
    innovation_instances.append(inno_string)
    
    
with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)
    
    print(data)
# Out:
# {'http://www.aboutamazon.com/our-company/': (['From the lab to the fulfillment center, employees contributed to the innovations behind a mailer that can be recycled in the same bin as Amazon’s iconic box.', 'Our innovations', 2], 'About Amazon'), 'http://www.intel.com/content/www/us/en/company-overview/company-overview.html': (['\r\n        <div class="language-selector-block">\r\n            <div class="modal-content flyout-panel-block force-background" role="dialog"\r\n                 aria-labelledby="regionselector" aria-describedby="selectregion">\r\n                <div class="modal-header flyout-panel-block-header">\r\n                        \r\n                    <h2 class="modal-title" id="Region-Modal">\r\n                        <span class="icon fa-globe align-icons"></span>\r\n                        Select Your Region\r\n                        <div id="close_button" class="modal-footer flyout-panel-block-header">\r\n                            <button type="button" class="close icon" aria-label="Close" data-igm-search-toggle="">\r\n                                <span></span>\r\n                            </button>\r\n                        </div>\r\n                    </h2>\r\n                </div>\r\n                <div class="modal-body lang-selector-body">\r\n                    <div class="flyout-control-panel">\r\n                        <ul class="list-unstyled flyout-control-listing" id="language-accordion">\r\n\r\n                            {{#if alsoAvail}}\r\n                            <div class="col-xs-12 lang-selector">\r\n                                <h4 class="accordion-toggle fa- expanded" data-toggle="collapse"\r\n                                    data-parent="#language-accordion"\r\n                                    data-target="#header-translations">\r\n                                    {{localeTitle}}</h4>\r\n                            </div>\r\n                            {{#each sections}}\r\n                            <div id="header-translations" class="accordion-panel in">\r\n                                {{#each locale}}\r\n                                {{regionNames languageList @index countryName}}\r\n                                {{/each}}\r\n                            </div>\r\n                            {{/each}}\r\n                            {{/if}}\r\n\r\n                            <div class="col-xs-12 lang-selector">\r\n                                <h4 class="accordion-toggle fa- {{#if alsoAvail}}collapsed{{else}}expanded{{/if}}"\r\n                                    data-toggle="collapse"\r\n                                    data-parent="#language-accordion"\r\n                                    data-target="#home-redirects">\r\n                                    {{homepageTitle}}</h4>\r\n                            </div>\r\n                            {{#each sections}}\r\n                            <div id="home-redirects"\r\n                                 class="accordion-panel {{#if ../alsoAvail}}collapse{{else}}in{{/if}}">\r\n                                {{#each locale}}\r\n                                <li>\r\n                                    <a href="#homepage-{{@index}}" data-toggle="flyout" class="flyout-control">{{{countryName}}}<span\r\n                                            class="icon-caret fa-angle-right"></span></a>\r\n                                </li>\r\n                                {{/each}}\r\n                            </div>\r\n                            {{/each}}\r\n\r\n                        </ul>\r\n                        {{#each sections}}\r\n                        {{#each locale}}\r\n                        {{storeIndex @index}}\r\n\r\n                        <div class="flyout-panel flyout-panel-position-right flyout-panel-closed force-background"\r\n                             id="geo-{{getIndex}}">\r\n                            <div class="flyout-panel-inner">\r\n                 ...

# %%
first_title = soup.title
print(first_title)
# Out:
# <title>About Amazon</title>

# %%
first_title.string
# Out:
# 'About Amazon'

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify()[0:1000])
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="http://www.epizyme.com/xmlrpc.php" rel="pingback"/>
#   <script type="text/javascript">
#    var switchTo5x = false;
#   </script>
#   <script src="http://w.sharethis.com/button/buttons.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    stLight.options( {
# 			publisher: "811cb0e1-501d-49e7-9206-5f1e6a169fd7",
# 			doNotHash: true,
# 			doNotCopy: true,
# 			hashAddressBar: false
# 		} );
#   </script>
#   <title>
#    Overview - Epizyme
#   </title>
#   <!-- This site is optimized with the Yoast SEO plugin v12.6.2 - https://yoast.com/wordpress/plugins/seo/ -->
#   <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots">
#    <link href="http://www.epizyme.com/about-us/overview-history/" rel="canonical">
#     <meta content="en_US" property="og:locale"

# %%
text_only = soup.get_text()
type(text_only)
# Out:
# str

# %%
from bs4 import BeautifulSoup
import urllib.request
import re
from IPython.display import HTML
import requests
from urllib import request, response, error, parse
from urllib.request import urlopen
import json

#Use "String slices" and .title() method to entract name of company after 'http://www.'
# remove s from https
# add logic that skips URLs that give `HTTPError` OR add logic to bypass HTTP Error 403 - https://stackoverflow.com/questions/13055208/httperror-http-error-403-forbidden
# used US companies only

urls = ['http://www.aboutamazon.com/our-company/', 
        'http://www.intel.com/content/www/us/en/company-overview/company-overview.html',
        'http://www.microsoft.com/en-us/about/',
        'http://corporate.ford.com/company.html',
        'http://www.boeing.com/company/general-info/',
        'http://www.alliancedata.com/about-us/default.aspx',
        'https://www.polarityte.com/about/overview/',
        'http://www.arconic.com/what-we-do/',
        'http://www.fico.com/en/about-us/',
        'http://www.epizyme.com/about-us/overview-history/']

data = {}

for url in urls:
    
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    
    first_title = soup.title
    
    title = first_title.string
    innovation_instances = soup.find_all(string=re.compile("inno*"))
    
    def listToString():  
        ii_string = " " 

        # return string   
        return (ii_string.join(innovation_instances)) 

    string = listToString()
    sub = 'inno'
    
#     innovation_instances.append(inno_string_count)
    
    
    # add count of innovation words to dictionary and print as JSON/CSV element under 
    
    
#     text_only = soup.get_text()
#     sub = 'inno'
#     inno_string_count = (string.count(sub))
    
    data[url] = innovation_instances, title, inno_string_count
    

    
    
with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)
    
    print(data)
# Out:
# {'http://www.aboutamazon.com/our-company/': (['From the lab to the fulfillment center, employees contributed to the innovations behind a mailer that can be recycled in the same bin as Amazon’s iconic box.', 'Our innovations'], 'About Amazon', 0), 'http://www.intel.com/content/www/us/en/company-overview/company-overview.html': (['\r\n        <div class="language-selector-block">\r\n            <div class="modal-content flyout-panel-block force-background" role="dialog"\r\n                 aria-labelledby="regionselector" aria-describedby="selectregion">\r\n                <div class="modal-header flyout-panel-block-header">\r\n                        \r\n                    <h2 class="modal-title" id="Region-Modal">\r\n                        <span class="icon fa-globe align-icons"></span>\r\n                        Select Your Region\r\n                        <div id="close_button" class="modal-footer flyout-panel-block-header">\r\n                            <button type="button" class="close icon" aria-label="Close" data-igm-search-toggle="">\r\n                                <span></span>\r\n                            </button>\r\n                        </div>\r\n                    </h2>\r\n                </div>\r\n                <div class="modal-body lang-selector-body">\r\n                    <div class="flyout-control-panel">\r\n                        <ul class="list-unstyled flyout-control-listing" id="language-accordion">\r\n\r\n                            {{#if alsoAvail}}\r\n                            <div class="col-xs-12 lang-selector">\r\n                                <h4 class="accordion-toggle fa- expanded" data-toggle="collapse"\r\n                                    data-parent="#language-accordion"\r\n                                    data-target="#header-translations">\r\n                                    {{localeTitle}}</h4>\r\n                            </div>\r\n                            {{#each sections}}\r\n                            <div id="header-translations" class="accordion-panel in">\r\n                                {{#each locale}}\r\n                                {{regionNames languageList @index countryName}}\r\n                                {{/each}}\r\n                            </div>\r\n                            {{/each}}\r\n                            {{/if}}\r\n\r\n                            <div class="col-xs-12 lang-selector">\r\n                                <h4 class="accordion-toggle fa- {{#if alsoAvail}}collapsed{{else}}expanded{{/if}}"\r\n                                    data-toggle="collapse"\r\n                                    data-parent="#language-accordion"\r\n                                    data-target="#home-redirects">\r\n                                    {{homepageTitle}}</h4>\r\n                            </div>\r\n                            {{#each sections}}\r\n                            <div id="home-redirects"\r\n                                 class="accordion-panel {{#if ../alsoAvail}}collapse{{else}}in{{/if}}">\r\n                                {{#each locale}}\r\n                                <li>\r\n                                    <a href="#homepage-{{@index}}" data-toggle="flyout" class="flyout-control">{{{countryName}}}<span\r\n                                            class="icon-caret fa-angle-right"></span></a>\r\n                                </li>\r\n                                {{/each}}\r\n                            </div>\r\n                            {{/each}}\r\n\r\n                        </ul>\r\n                        {{#each sections}}\r\n                        {{#each locale}}\r\n                        {{storeIndex @index}}\r\n\r\n                        <div class="flyout-panel flyout-panel-position-right flyout-panel-closed force-background"\r\n                             id="geo-{{getIndex}}">\r\n                            <div class="flyout-panel-inner">\r\n                 ...

# %%
urls = ['http://www.aboutamazon.com/our-company/', 
        'http://www.intel.com/content/www/us/en/company-overview/company-overview.html',
        'http://www.microsoft.com/en-us/about/',
        'http://corporate.ford.com/company.html',
        'http://www.boeing.com/company/general-info/',
        'http://www.alliancedata.com/about-us/default.aspx',
        'https://www.polarityte.com/about/overview/',
        'http://www.arconic.com/what-we-do/',
        'http://www.fico.com/en/about-us/',
        'http://www.epizyme.com/about-us/overview-history/']

data = {}

for url in urls:
    
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    
    
    
    
    first_title = soup.title
    title = first_title.string
    
    
    innovation_instances = soup.find_all(string=re.compile("inno+"))

#     for instances in innovation_instances:
        
    
    def listToString():  
        ii_string = " " 

        # return string   
        return (ii_string.join(innovation_instances)) 

    string = listToString()
    sub = 'inno'
    
    inno_string_count = (string.count(sub))
    
    data[url] = innovation_instances, title, inno_string_count
    
print(data)
    

with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)
# Out:
# {'http://www.aboutamazon.com/our-company/': (['From the lab to the fulfillment center, employees contributed to the innovations behind a mailer that can be recycled in the same bin as Amazon’s iconic box.', 'Our innovations'], 'About Amazon', 2), 'http://www.intel.com/content/www/us/en/company-overview/company-overview.html': ([], 'Intel Company Overview', 0), 'http://www.microsoft.com/en-us/about/': (['At Microsoft, we’re moved and inspired by many things. Microsoft Story Labs features in-depth interviews, features, and stories with those that are on the forefront of innovation.'], 'About Microsoft | Mission and Vision | Microsoft', 1), 'http://corporate.ford.com/company.html': (['Today, Ford Motor Company touches the lives of people in every corner of the globe, not just by making and selling the most technologically advanced, reliable and fun-to-drive vehicles in the world, but by leading the way in manufacturing and business innovation.'], 'Ford Motor Company: Company Information | Ford.com', 1), 'http://www.boeing.com/company/general-info/': (['Boeing has a long tradition of aerospace leadership and innovation. The company continues to expand its product line and services to meet emerging customer needs. Its broad range of capabilities includes creating new, more efficient members of its commercial airplane family; designing, building and integrating military platforms and defense systems; creating advanced technology solutions; and arranging innovative financing and service options for customers.', 'With corporate offices in Chicago, Boeing employs more than 153,000 people across the United States and in more than 65 countries. This represents one of the most diverse, talented and innovative workforces anywhere. Our enterprise also leverages the talents of hundreds of thousands more skilled people working for Boeing suppliers worldwide.', 'Defense, Space & Security (BDS) is a diversified, global organization providing leading solutions for the design, production, modification, service and support of commercial derivatives, military rotorcraft, satellites, human space exploration and autonomous systems. It helps customers address a host of requirements through a broad portfolio that includes KC-46 aerial refueling aircraft, based on the Boeing 767 commercial airplane; AH-64 Apache helicopter; the 702 family of satellites; CST-100 Starliner spacecraft; and the autonomous Echo Voyager. Driven by the Boeing vision to connect, protect, explore and inspire the world through aerospace innovation, BDS is seeking ways to better leverage information technologies and continues to invest in the research and development of enhanced capabilities and platforms.', "As the leading manufacturer for commercial and defense platforms, Boeing is positioned to provide unparalleled aftermarket support for mixed fleets worldwide. Boeing Global Services delivers innovative, comprehensive and cost-competitive service solutions for commercial, defense and space customers, regardless of the equipment's original manufacturer. With engineering, digital analytics, supply chain and training support spanning across both the government and commercial service offerings, Boeing Global Services’ unsurpassed, around-the-clock support keeps our customers’ commercial aircraft operating at high efficiency, and provides mission assurance for nations around the world."], 'Boeing: The Boeing Company: General Information', 5), 'http://www.alliancedata.com/about-us/default.aspx': ([], '\r\n\tAlliance Data Systems - About Us\r\n', 0), 'https://www.polarityte.com/about/overview/': (['We are revolutionizing regenerative medicine and inducing a paradigm shift through our innovative platform technology, incredible team, expanding network and drive to be different.'], 'About :: PolarityTE, Inc.(PTE) :: PolarityTE, Inc. (PTE)', 1), 'http://www.arconic.com/what-we-do/': (['We’ve helped push the boundaries of aviation since the dawn of flight.\xa0 From the engine block of the ...

# %%
urls = [
        'http://www.aboutamazon.com/our-company/',
        'http://www.intel.com/content/www/us/en/company-overview/company-overview.html']
#         'http://www.microsoft.com/en-us/about/',
#         'http://corporate.ford.com/company.html',
#         'http://www.boeing.com/company/general-info/',
#         'http://www.alliancedata.com/about-us/default.aspx',
#         'https://www.polarityte.com/about/overview/',
#         'http://www.arconic.com/what-we-do/',
#         'http://www.fico.com/en/about-us/',
#         'http://www.epizyme.com/about-us/overview-history/']

data = {}

for url in urls:
    
    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')
    
    # generate title
    first_title = soup.title
    title = first_title.string
    
    # create list of all instances of the word innovation, or some version of it
    innovation_instances = soup.find_all(string=re.compile("inno+"))

        
    #convert list to string and count how many times innovation is mentioned
    def listToString():  
        ii_string = " " 

        # return string   
        return (ii_string.join(innovation_instances)) 

    string = listToString()
    sub = 'inno'
    
    inno_string_count = (string.count(sub))
    
    num_words = [len(sentence.split()) for sentence in soup.find_all(string=re.compile("inno+"))]
    
    frequency = (int(inno_string_count) / num_words[0]) * 100
    
    
    data[url] = innovation_instances, title, inno_string_count, num_words[0], frequency 
    
    print(data)
    
# print(data)
    

# with open('data.txt', 'w') as outfile:
#     json.dump(data, outfile)
# Out:
# {'http://www.aboutamazon.com/our-company/': (['From the lab to the fulfillment center, employees contributed to the innovations behind a mailer that can be recycled in the same bin as Amazon’s iconic box.', 'Our innovations'], 'About Amazon', 2, 27, 7.4074074074074066)}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-198-f3827f5c6b83> in <module>
#      40     num_words = [len(sentence.split()) for sentence in soup.find_all(string=re.compile("inno+"))]
#      41
# ---> 42     frequency = (int(inno_string_count) / num_words[0]) * 100
#      43
#      44
#
# IndexError: list index out of range

# %%
print(num_words)
# Out:
# []
